# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('Shenzhen_Clean.csv')
# Out:
#        Year     Month   Day  Month #  Day #  Week#  Kitchen waste (t)  \
# 0    2015.0  December   1.0      1.0    1.0    1.0              92.03
# 1    2015.0  December   2.0      1.0    2.0    1.0              78.43
# 2    2015.0  December   3.0      1.0    3.0    1.0              81.84
# 3    2015.0  December   4.0      1.0    4.0    1.0              81.05
# 4    2015.0  December   5.0      1.0    5.0    1.0              36.86
# 5    2015.0  December   6.0      1.0    6.0    1.0              21.58
# 6    2015.0  December   7.0      1.0    7.0    1.0              89.98
# 7    2015.0  December   8.0      1.0    8.0    2.0              80.46
# 8    2015.0  December   9.0      1.0    9.0    2.0              77.20
# 9    2015.0  December  10.0      1.0   10.0    2.0              78.37
# 10   2015.0  December  11.0      1.0   11.0    2.0              74.03
# 11   2015.0  December  12.0      1.0   12.0    2.0              38.38
# ...

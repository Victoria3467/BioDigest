# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().magic('matplotlib inline')
sns.set(style='white', context='notebook', palette='deep')
plt.rcParams[ 'figure.figsize' ] = 9 , 5

# %%
xl = pd.ExcelFile("HainanData_kindofClean.xlsx")

# %%
df = xl.parse("Clean")
df.shape
# Out:
# (1035, 30)

# %%
nan_rows = df[df['day #2'].isnull()]
nan_rows
# Out:
#      Year     Month  Day  Month #  Day #  Raw Biogas Produced (m3)  \
# 0    2014       May    1        1      1                       0.0
# 1    2014       May    2        1      2                       0.0
# 2    2014       May    3        1      3                       0.0
# 3    2014       May    4        1      4                       0.0
# 4    2014       May    5        1      5                       0.0
# 5    2014       May    6        1      6                       0.0
# 6    2014       May    7        1      7                       0.0
# 7    2014       May    8        1      8                       0.0
# 8    2014       May    9        1      9                       0.0
# 9    2014       May   10        1     10                       0.0
# 10   2014       May   11        1     11                       0.0
# 11   2014       May   12        1     12                       0.0
# 12   2014       May   13        1     13                       0.0
# ...

# %%
df.drop(['Day', 'Year', 'Water/m3', 'Total electricity cons (kWh)', '50% NaOH/kg', 'FeCl2/kg', 'PAM/kg', 'Defoamer/kg', 'day #2'], axis = 1, inplace = True)

# %%
df.describe()
# Out:
#            Month #        Day #  Raw Biogas Produced (m3)  \
# count  1035.000000  1035.000000               1035.000000
# mean     17.471498   518.000000               5557.376663
# std       9.806637   298.923067               5056.098003
# min       1.000000     1.000000                  0.000000
# 25%       9.000000   259.500000                  0.000000
# 50%      17.000000   518.000000               4729.000000
# 75%      26.000000   776.500000               8387.000000
# max      34.000000  1035.000000              23619.000000
#
#        BioCNG Produced (Nm3)  BioCNG Sold (m3)  \
# count            1035.000000       1035.000000
# mean             3695.784541       3882.645952
# std              2442.241748       3176.084805
# min                 0.000000          0.000000
# 25%              2112.000000        140.565000
# 50%              3106.000000       3924.000000
# 75%              4742.000000       4648.000000
# max             13350.000000      16530.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 21 columns):
# Month                             1035 non-null object
# Month #                           1035 non-null int64
# Day #                             1035 non-null int64
# Raw Biogas Produced (m3)          1035 non-null float64
# BioCNG Produced (Nm3)             1035 non-null int64
# BioCNG Sold (m3)                  1035 non-null float64
# Liquid Fertilizer Produced (t)    1035 non-null float64
# Liquid fertilizer sold (t)        1035 non-null float64
# Solid fertilizer produced (t)     1035 non-null float64
# Solid fertilizer sold (t)         1035 non-null float64
# Manure input (t)                  1035 non-null float64
# Bagasse 1 input (t)               1035 non-null float64
# Lees (fermentation)               1035 non-null float64
# Fish waste input (t)              1035 non-null float64
# Alcowaste input (t)               1035 non-null float64
# ...

# %%
#number of zeros
df.astype(bool).sum(axis=0)
# Out:
# Month                             1035
# Month #                           1035
# Day #                             1035
# Raw Biogas Produced (m3)           772
# BioCNG Produced (Nm3)             1001
# BioCNG Sold (m3)                   803
# Liquid Fertilizer Produced (t)     496
# Liquid fertilizer sold (t)         496
# Solid fertilizer produced (t)      257
# Solid fertilizer sold (t)          257
# Manure input (t)                   850
# Bagasse 1 input (t)                631
# Lees (fermentation)                143
# Fish waste input (t)               223
# Alcowaste input (t)                172
# Cassava input (t)                  253
# Grass input (t)                    102
# Tea waste input (t)                 58
# Other input (t)                    255
# Total input (t)                    962
# Diesel cons/L                      313
# dtype: int64

# %%
Month_CNG = df[['Month', 'BioCNG Produced (Nm3)']].groupby(['Month']).mean()
Month_CNG
# Out:
#            BioCNG Produced (Nm3)
# Month
# April                4246.066667
# August               2509.731183
# December             4438.741935
# February             5458.905882
# January              7088.720430
# July                 3492.430108
# June                 2644.215909
# June                 3535.500000
# March                5268.500000
# May                  4104.344086
# November             2275.266667
# October              1491.440860
# September            2050.222222

# %%
LABELS = Month_CNG.index
Month = list(range(13))
CNG_month = Month_CNG['BioCNG Produced (Nm3)']
a = []
for i in CNG_month:
    a.append(i)


plt.figure(figsize = (10,10))
plt.bar(Month, a, align='center')
plt.xticks(Month, LABELS)
plt.plot(df['BioCNG Produced (Nm3)'].describe().mean())

# %%
Fish_CNG = df[['Fish waste input (t)', 'BioCNG Produced (Nm3)']].groupby(['Fish waste input (t)']).mean()
Fish_CNG.head()
# Out:
#                       BioCNG Produced (Nm3)
# Fish waste input (t)
# 0.00                             3532.29803
# 2.00                             3947.00000
# 2.34                             3125.00000
# 2.66                             3847.00000
# 2.88                             1450.00000

# %%
#plt.scatter(df['Fish waste input (t)'], df['BioCNG Sold (m3)'])
Fish_CNG2 = Fish_CNG['BioCNG Produced (Nm3)']
b = []
for i in Fish_CNG2:
    b.append(i)
#print(b)
plt.scatter(Fish_CNG.index, b)

# %%
Total_CNG = df[['Total input (t)', 'BioCNG Produced (Nm3)']].groupby(['Total input (t)']).mean()
Total_CNG.head()
# Out:
#                  BioCNG Produced (Nm3)
# Total input (t)
# 0.00                        911.410959
# 1.26                       1630.000000
# 2.78                       2602.000000
# 2.82                       2244.000000
# 2.88                       1450.000000

# %%
Total_CNG2 = Total_CNG['BioCNG Produced (Nm3)']
c = []
for i in Total_CNG2:
    c.append(i)
#print(c)
plt.scatter(Total_CNG.index, c)

# %%
Tea_CNG = df[['Tea waste input (t)', 'BioCNG Produced (Nm3)']].groupby(['Tea waste input (t)']).mean()
Tea_CNG.head()

Tea_CNG2 = Tea_CNG['BioCNG Produced (Nm3)']
d = []
for i in Tea_CNG2:
    d.append(i)
#print(c)
plt.scatter(Tea_CNG.index, d)

# %%
Grass_CNG = df[['Grass input (t)', 'BioCNG Produced (Nm3)']].groupby(['Grass input (t)']).mean()
Grass_CNG.head()

Grass_CNG2 = Grass_CNG['BioCNG Produced (Nm3)']
d = []
for i in Grass_CNG2:
    d.append(i)
#print(c)
plt.scatter(Grass_CNG.index, d)

# %%
Cassava_CNG = df[['Cassava input (t)', 'BioCNG Produced (Nm3)']].groupby(['Cassava input (t)']).mean()
Cassava_CNG.head()

Cassava_CNG2 = Cassava_CNG['BioCNG Produced (Nm3)']
d = []
for i in Cassava_CNG2:
    d.append(i)
#print(c)
plt.scatter(Cassava_CNG.index, d)

# %%
Alcowaste_CNG = df[['Alcowaste input (t)', 'BioCNG Produced (Nm3)']].groupby(['Alcowaste input (t)']).mean()
Alcowaste_CNG.head()

Alcowaste_CNG2 = Alcowaste_CNG['BioCNG Produced (Nm3)']
d = []
for i in Alcowaste_CNG2:
    d.append(i)
#print(c)
plt.scatter(Alcowaste_CNG.index, d)

# %%
Manure_CNG = df[['Manure input (t)', 'BioCNG Produced (Nm3)']].groupby(['Manure input (t)']).mean()
Manure_CNG.head()

Manure_CNG2 = Manure_CNG['BioCNG Produced (Nm3)']
d = []
for i in Manure_CNG2:
    d.append(i)
#print(c)
plt.scatter(Manure_CNG.index, d)

# %%
Bagasse_CNG = df[['Bagasse 1 input (t)', 'BioCNG Produced (Nm3)']].groupby(['Bagasse 1 input (t)']).mean()
Bagasse_CNG.head()

Bagasse_CNG2 = Bagasse_CNG['BioCNG Produced (Nm3)']
d = []
for i in Bagasse_CNG2:
    d.append(i)
#print(c)
plt.scatter(Bagasse_CNG.index, d)

# %%
Fermented_CNG = df[['Lees (fermentation)', 'BioCNG Produced (Nm3)']].groupby(['Lees (fermentation)']).mean()
Fermented_CNG.head()

Fermented_CNG2 = Fermented_CNG['BioCNG Produced (Nm3)']
d = []
for i in Fermented_CNG2:
    d.append(i)
#print(c)
plt.scatter(Fermented_CNG.index, d)
